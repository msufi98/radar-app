# %% [markdown]
# # NEXRAD Level 2 Parser Verification - PyART
# This notebook tests the PyART NEXRAD Level 2 parser and outputs results for comparison

# %%
# %pip install boto3
# Out:
# Collecting boto3
#   Using cached boto3-1.40.45-py3-none-any.whl.metadata (6.7 kB)
# Collecting botocore<1.41.0,>=1.40.45 (from boto3)
#   Using cached botocore-1.40.45-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\moiyyad\projects\uihi\nexrad-converter\.conda\lib\site-packages (from boto3) (1.0.1)
# Collecting s3transfer<0.15.0,>=0.14.0 (from boto3)
#   Using cached s3transfer-0.14.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\moiyyad\projects\uihi\nexrad-converter\.conda\lib\site-packages (from botocore<1.41.0,>=1.40.45->boto3) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\moiyyad\projects\uihi\nexrad-converter\.conda\lib\site-packages (from botocore<1.41.0,>=1.40.45->boto3) (2.5.0)
# Requirement already satisfied: six>=1.5 in c:\moiyyad\projects\uihi\nexrad-converter\.conda\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.45->boto3) (1.17.0)
# Downloading boto3-1.40.45-py3-none-any.whl (139 kB)
# Downloading botocore-1.40.45-py3-none-any.whl (14.1 MB)
#    ---------------------------------------- 0.0/14.1 MB ? eta -:--:--
#    --------- ------------------------------ 3.4/14.1 MB 16.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 8.4/14.1 MB 20.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 12.3/14.1 MB 22.0 MB/s eta 0:00:01
#    ---------------------------------------  13.9/14.1 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------------- 14.1/14.1 MB 14.5 MB/s  0:00:00
# Downloading s3transfer-0.14.0-py3-none-any.whl (85 kB)
# Installing collected packages: botocore, s3transfer, boto3
#
#   Attempting uninstall: botocore
#
#     Found existing installation: botocore 1.40.18
#
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#     Uninstalling botocore-1.40.18:
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#       Successfully uninstalled botocore-1.40.18
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ---------------------------------------- 0/3 [botocore]
#    ------------- -------------------------- 1/3 [s3transfer]
#    ------------- -------------------------- 1/3 [s3transfer]
#    ------------- -------------------------- 1/3 [s3transfer]
#    -------------------------- ------------- 2/3 [boto3]
#    -------------------------- ------------- 2/3 [boto3]
#    -------------------------- ------------- 2/3 [boto3]
#    -------------------------- ------------- 2/3 [boto3]
#    -------------------------- ------------- 2/3 [boto3]
#    -------------------------- ------------- 2/3 [boto3]
#    ---------------------------------------- 3/3 [boto3]
#
# Successfully installed boto3-1.40.45 botocore-1.40.45 s3transfer-0.14.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiobotocore 2.24.2 requires botocore<1.40.19,>=1.40.15, but you have botocore 1.40.45 which is incompatible.

# %%
import pyart
from pyart.io.nexrad_level2 import NEXRADLevel2File
import boto3
from botocore import UNSIGNED
from botocore.config import Config
import json
import numpy as np
from datetime import datetime

# %%
# Download a sample NEXRAD file from S3
# Using: 2013/05/06/KABR (site that appeared in the AWS CLI example)

s3 = boto3.client('s3', config=Config(signature_version=UNSIGNED))
bucket = 'unidata-nexrad-level2'
prefix = '2013/05/06/KABR/'

# List files for this date/site
response = s3.list_objects_v2(Bucket=bucket, Prefix=prefix, MaxKeys=1)

if 'Contents' in response and len(response['Contents']) > 0:
    # Get the first file
    file_key = response['Contents'][0]['Key']
    # Extract filename from the key
    remote_filename = file_key.split('/')[-1]
    local_file = f'data/{remote_filename}'
    
    print(f'Downloading: {file_key}')
    s3.download_file(bucket, file_key, local_file)
    print(f'Downloaded to: {local_file}')
    print(f'File key saved for Node.js test: {file_key}')
    
    # Save file info for Node.js
    with open('data/test_file_info.json', 'w') as f:
        json.dump({'key': file_key, 'local_path': local_file}, f, indent=2)
else:
    print('No files found for this date/site')
# Out:
# Downloading: 2013/05/06/KABR/KABR20130506_000526_V06.gz
# Downloaded to: data/KABR20130506_000526_V06.gz
# File key saved for Node.js test: 2013/05/06/KABR/KABR20130506_000526_V06.gz

# %%
# Use prepare_for_read to decompress and open the file, then parse with NEXRADLevel2File
from pyart.io.common import prepare_for_read

# Prepare the file for reading (handles decompression)
file_handle = prepare_for_read(local_file, storage_options={})

# Parse using NEXRADLevel2File directly
nexrad_file = NEXRADLevel2File(file_handle)

print('File parsed successfully with NEXRADLevel2File!')
print(f'Volume header info:')
print(f'  - Volume number: {nexrad_file.volume_header}')
print(f'  - Number of message_31 records: {len(nexrad_file.msg31_data_block_headers) if hasattr(nexrad_file, "msg31_data_block_headers") else "N/A"}')
# Out:
# File parsed successfully with NEXRADLevel2File!
# Volume header info:
#   - Volume number: {'tape': b'AR2V0006.', 'extension': b'843', 'date': 15832, 'time': 329000, 'icao': b'KABR'}
#   - Number of message_31 records: N/A

# %%
# Extract data using NEXRADLevel2File class methods
output = {
    'volume_header': nexrad_file.volume_header,
    'vcp': nexrad_file.vcp,
    'nscans': nexrad_file.nscans,
    'location': nexrad_file.location(),
    'vcp_pattern': nexrad_file.get_vcp_pattern(),
}

# Get scan information for all scans
output['scan_info'] = nexrad_file.scan_info()

# Get times, angles, and velocities for all scans
output['times'] = nexrad_file.get_times()
output['azimuth_angles'] = nexrad_file.get_azimuth_angles()
output['elevation_angles'] = nexrad_file.get_elevation_angles()
output['target_angles'] = nexrad_file.get_target_angles()
output['nyquist_vel'] = nexrad_file.get_nyquist_vel()
output['unambiguous_range'] = nexrad_file.get_unambigous_range()

# Get number of rays for each scan
output['nrays_per_scan'] = {}
for scan in range(nexrad_file.nscans):
    output['nrays_per_scan'][f'scan_{scan}'] = nexrad_file.get_nrays(scan)

print('Data extraction complete!')
print(json.dumps(output, indent=2, default=str))
# Out:
# Data extraction complete!
# {
#   "volume_header": {
#     "tape": "b'AR2V0006.'",
#     "extension": "b'843'",
#     "date": 15832,
#     "time": 329000,
#     "icao": "b'KABR'"
#   },
#   "vcp": {
#     "header": {
#       "size": 180,
#       "channels": 8,
#       "type": 5,
#       "seq_id": 39315,
#       "date": 15832,
#       "ms": 326622,
#       "segments": 1,
#       "seg_num": 1
#     },
#     "msg5_header": {
#       "msg_size": 172,
#       "pattern_type": 2,
#       "pattern_number": 32,
#       "num_cuts": 7,
#       "clutter_map_group": 1,
#       "doppler_vel_res": 2,
#       "pulse_width": 2,
#       "spare": "b'\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00\\x00'"
#     },
#     "cut_parameters": [
#       {
#         "elevation_angle": 88,
#         "channel_config": 0,
#         "waveform_type": 1,
#         "super_resolution": 11,
#         "prf_number": 1,
#         "prf_pulse_count": 64,
#         "azimuth_rate": 3616,
#         "ref_thresh": 4,
#         "vel_thresh": 4,
#         "sw_thresh": 4,
#         "zdr_thres": 4,
#         "phi_thres": 4,
#         "rho_thres": 4,
#         "edge_angle_1": 0,
#         "dop_prf_num_1": 0,
#         "dop_prf_pulse_count_1": 0,
#         "spare_1": "b'\\x00\\x00'",
#         "edge_angle_2": 0,
#         "dop_prf_num_2": 0,
#         "dop_prf_pulse_count_2": 0,
#         "spare_2": "b'\\x00\\x00'",
#         "edge_angle_3": 0,
#         "dop_prf_num_3": 0,
#         "dop_prf_pulse_count_3": 0,
#         "spare_3": "b'\\x00\\x00'"
#       },
#       {
#         "elevation_angle": 88,
#         "channel_config": 0,
#         "waveform_type": 2,
#         "super_resolution": 7,
#         "prf_number": 0,
#         "prf_pulse_count": 0,
#         "azimuth_rate": 3312,
#         "ref_thresh": 4,
#         "vel_thresh": 4,
#         "sw_thresh": 4,
#         "zdr_thres": 4,
#         "phi_thres": 4,
#         "rho_thres": 4,
#         "edge_angle_1": 5464,
#         "dop_prf_num_1": 5,
#         "dop_prf_pulse_count_1": 220,
#         "spare_1": "b'\\x00\\x00'",
#         "edge_angle_2": 38232,
#         "dop_prf_num_2": 5,
#         "dop_prf_pulse_count_2": 220,
#         "spare_2": "b'\\x00\\x00'",
#         "edge_angle_3": 60984,
#         "dop_prf_num_3": 5,
#         "dop_prf_pulse_count_3": 220,
#         "spare_3": "b'\\x00\\x00'"
#       },
#       {
#         "elevation_angle": 272,
#         "channel_config": 0,
#         "waveform_type": 1,
#         "super_resolution": 11,
#         "prf_number": 1,
#         "prf_pulse_count": 64,
#         "azimuth_rate": 3616,
#         "ref_thresh": 4,
#         "vel_thresh": 4,
#         "sw_thresh": 4,
#         "zdr_thres": 4,
#         "phi_thres": 4,
#         "rho_thres": 4,
#         "edge_angle_1": 0,
#         "dop_prf_num_1": 0,
#         "dop_prf_pulse_count_1": 0,
#         "spare_1": "b'\\x00\\x00'",
#         "edge_angle_2": 0,
#         "dop_prf_num_2": 0,
#         "dop_prf_pulse_count_2": 0,
#         "spare_2": "b'\\x00\\x00'",
#         "edge_angle_3": 0,
#         "dop_prf_num_3": 0,
#         "dop_prf_pulse_count_3": 0,
#         "spare_3": "b'\\x00\\x00'"
#       },
#       {
#         "elevation_angle": 272,
#         "channel_config": 0,
#         "waveform_type": 2,
#         "super_resolution": 7,
#         "prf_number": 0,
#         "prf_pulse_count": 0,
#         "azimuth_rate": 3312,
#         "ref_thresh": 4,
#         "vel_thresh": 4,
#         "sw_thresh": 4,
#         "zdr_thres": 4,
#         "phi_thres": 4,
#         "rho_thres": 4,
#         "edge_angle_1": 5464,
#         "dop_prf_num_1": 5,
#         "dop_prf_pulse_count_1": 220,
#         "spare_1": "b'\\x00\\x00'",
#         "edge_angle_2": 38232,
#         "dop_prf_num_2": 5,
#         "dop_prf_pulse_count_2": 220,
#         "spare_2": "b'\\x00\\x00'",
#         "edge_angle_3": 60984,
#         "dop_prf_num_3": 5,
#         "dop_prf_pulse_count_3": 220,
#         "spare_3": "b'\\x00\\x00'"
#       },
#       {
#         "elevation_angle": 456,
#         "channel_config": 0,
#         "waveform_type": 4,
#         "super_resolution": 14,
#         "prf_number": 2,
#         "prf_pulse_count": 11,
#         "azimuth_rate": 2960,
#         "ref_thresh": 8,
#         "vel_thresh": 8,
#         "sw_thresh": 8,
#         "zdr_thres": 8,
#         "phi_thres": 8,
#         "rho_thres": 8,
#         "edge_angle_1": 5464,
#         "dop_prf_num_1": 5,
#         "dop_prf_pulse_count_1": 220,
#         "spare_1": "b'\\x00\\x00'",
#         "edge_angle_2": 38232,
#         "dop_prf_num_2": 5,
#         "dop_prf_pulse_count_2": 220,
#         "spare_2": "b'\\x00\\x00'",
#         "edge_angle_3": 60984,
#         "dop_prf_num_3": 5,
#         "dop_prf_pulse_count_3": 220,
#         "spare_3": "b'\\x00\\x00'"
#       },
#       {
#         "elevation_angle": 640,
#         "channel_config": 0,
#         "waveform_type": 4,
#         "super_resolution": 14,
#         "prf_number": 2,
#         "prf_pulse_count": 11,
#         "azimuth_rate": 2960,
#         "ref_thresh": 8,
#         "vel_thresh": 8,
#         "sw_thresh": 8,
#         "zdr_thres": 8,
#         "phi_thres": 8,
#         "rho_thres": 8,
#         "edge_angle_1": 5464,
#         "dop_prf_num_1": 5,
#         "dop_prf_pulse_count_1": 220,
#         "spare_1": "b'\\x00\\x00'",
#         "edge_angle_2": 38232,
#         "dop_prf_num_2": 5,
#         "dop_prf_pulse_count_2": 220,
#         "spare_2": "b'\\x00\\x00'",
#         "edge_angle_3": 60984,
#         "dop_prf_num_3": 5,
#         "dop_prf_pulse_count_3": 220,
#         "spare_3": "b'\\x00\\x00'"
#       },
#       {
#         "elevation_angle": 816,
#         "channel_config": 0,
#         "waveform_type": 4,
#         "super_resolution": 14,
#         "prf_number": 2,
#         "prf_pulse_count": 11,
#         "azimuth_rate": 2960,
#         "ref_thresh": 8,
#         "vel_thresh": 8,
#         "sw_thresh": 8,
#         "zdr_thres": 8,
#         "phi_thres": 8,
#         "rho_thres": 8,
#         "edge_angle_1": 5464,
#         "dop_prf_num_1": 5,
#         "dop_prf_pulse_count_1": 220,
#         "spare_1": "b'\\x00\\x00'",
#         "edge_angle_2": 38232,
#         "dop_prf_num_2": 5,
#         "dop_prf_pulse_count_2": 220,
#         "spare_2": "b'\\x00\\x00'",
#         "edge_angle_3": 60984,
#         "dop_prf_num_3": 5,
#         "dop_prf_pulse_count_3": 220,
#         "spare_3": "b'\\x00\\x00'"
#       }
#     ]
#   },
#   "nscans": 7,
#   "location": [
#     45.455833435058594,
#     -98.41278076171875,
#     420
#   ],
#   "vcp_pattern": 32,
#   "scan_info": [
#     {
#       "nrays": 720,
#       "ngates": [
#         1832,
#         1192,
#         1192,
#         1192
#       ],
#       "gate_spacing": [
#         250,
#         250,
#         250,
#         250
#       ],
#       "first_gate": [
#         2125,
#         2125,
#         2125,
#         2125
#       ],
#       "moments": [
#         "REF",
#         "ZDR",
#         "PHI",
#         "RHO"
#       ]
#     },
#     {
#       "nrays": 720,
#       "ngates": [
#         1192,
#         1192,
#         1192
#       ],
#       "gate_spacing": [
#         250,
#         250,
#         250
#       ],
#       "first_gate": [
#         2125,
#         2125,
#         2125
#       ],
#       "moments": [
#         "REF",
#         "VEL",
#         "SW"
#       ]
#     },
#     {
#       "nrays": 720,
#       "ngates": [
#         1648,
#         1192,
#         1192,
#         1192
#       ],
#       "gate_spacing": [
#         250,
#         250,
#         250,
#         250
#       ],
#       "first_gate": [
#         2125,
#         2125,
#         2125,
#         2125
#       ],
#       "moments": [
#         "REF",
#         "ZDR",
#         "PHI",
#         "RHO"
#       ]
#     },
#     {
#       "nrays": 720,
#       "ngates": [
#         1192,
#         1192,
#         1192
#       ],
#       "gate_spacing": [
#         250,
#         250,
#         250
#       ],
#       "first_gate": [
#         2125,
#         2125,
#         2125
#       ],
#       "moments": [
#         "REF",
#         "VEL",
#         "SW"
#       ]
#     },
#     {
#       "nrays": 360,
#       "ngates": [
#         1316,
#         1192,
#         1192,
#         1192,
#         1192,
#         1192
#       ],
#       "gate_spacing": [
#         250,
#         250,
#         250,
#         250,
#         250,
#         250
#       ],
#       "first_gate": [
#         2125,
#         2125,
#         2125,
#         2125,
#         2125,
#         2125
#       ],
#       "moments": [
#         "REF",
#         "VEL",
#         "SW",
#         "ZDR",
#         "PHI",
#         "RHO"
#       ]
#     },
#     {
#       "nrays": 360,
#       "ngates": [
#         1076,
#         1076,
#         1076,
#         1076,
#         1076,
#         1076
#       ],
#       "gate_spacing": [
#         250,
#         250,
#         250,
#         250,
#         250,
#         250
#       ],
#       "first_gate": [
#         2125,
#         2125,
#         2125,
#         2125,
#         2125,
#         2125
#       ],
#       "moments": [
#         "REF",
#         "VEL",
#         "SW",
#         "ZDR",
#         "PHI",
#         "RHO"
#       ]
#     },
#     {
#       "nrays": 360,
#       "ngates": [
#         904,
#         904,
#         904,
#         904,
#         904,
#         904
#       ],
#       "gate_spacing": [
#         250,
#         250,
#         250,
#         250,
#         250,
#         250
#       ],
#       "first_gate": [
#         2125,
#         2125,
#         2125,
#         2125,
#         2125,
#         2125
#       ],
#       "moments": [
#         "REF",
#         "VEL",
#         "SW",
#         "ZDR",
#         "PHI",
#         "RHO"
#       ]
#     }
#   ],
#   "times": [
#     "2013-05-06 00:05:26",
#     "[4.51000e-01 5.48000e-01 6.56000e-01 ... 5.58972e+02 5.59216e+02\n 5.59457e+02]"
#   ],
#   "azimuth_angles": "[21.25030518 21.74743652 22.25830078 ... 47.49664307 48.47991943\n 49.52636719]",
#   "elevation_angles": "[0.3515625  0.37353516 0.37353516 ... 4.48242188 4.48242188 4.48242188]",
#   "target_angles": "[0.48339844 0.48339844 1.4941406  1.4941406  2.5048828  3.515625\n 4.482422  ]",
#   "nyquist_vel": "[ 8.37  8.37  8.37 ... 26.35 26.35 26.35]",
#   "unambiguous_range": "[466000. 466000. 466000. ... 148000. 148000. 148000.]",
#   "nrays_per_scan": {
#     "scan_0": 720,
#     "scan_1": 720,
#     "scan_2": 720,
#     "scan_3": 720,
#     "scan_4": 360,
#     "scan_5": 360,
#     "scan_6": 360
#   }
# }

# %%
# Get available moments and their data
# Common NEXRAD moments: REF (reflectivity), VEL (velocity), SW (spectrum width), ZDR, PHI, RHO

moments_to_check = ['REF', 'VEL', 'SW', 'ZDR', 'PHI', 'RHO']
output['moments'] = {}

for moment in moments_to_check:
    try:
        # Get range information for first scan
        range_info = nexrad_file.get_range(0, moment)
        # Get data for this moment (using max_ngates from range info)
        max_ngates = len(range_info)
        data = nexrad_file.get_data(moment, max_ngates)
        
        output['moments'][moment] = {
            'available': True,
            'range_info': range_info.tolist() if hasattr(range_info, 'tolist') else list(range_info),
            'max_ngates': max_ngates,
            'data_shape': data.shape,
            'data_sample': data[0, :10].tolist() if len(data.shape) > 1 else []
        }
        print(f'Moment {moment}: Available, shape {data.shape}')
    except Exception as e:
        output['moments'][moment] = {'available': False, 'error': str(e)}
        print(f'Moment {moment}: Not available - {str(e)}')
# Out:
# Moment REF: Available, shape (3960, 1832)
# Moment VEL: Not available - 'VEL'
# Moment SW: Not available - 'SW'
# Moment ZDR: Available, shape (3960, 1192)
# Moment PHI: Available, shape (3960, 1192)
# Moment RHO: Available, shape (3960, 1192)

# %%
# Save output to file
with open('output/nexrad_level2_file_output.json', 'w') as f:
    json.dump(output, f, indent=2, default=str)

print('Output saved to: output/nexrad_level2_file_output.json')
# Out:
# Output saved to: output/nexrad_level2_file_output.json

# %%
# Summary
print(f"\n=== NEXRADLevel2File Summary ===")
print(f"Location: {output['location']}")
print(f"VCP Pattern: {output['vcp_pattern']}")
print(f"Number of scans: {output['nscans']}")
print(f"Available moments: {[m for m, info in output['moments'].items() if info.get('available', False)]}")
print(f"\nAnalysis complete!")
